# %% [markdown]
# ## <font color='darkblue'>Temporal Difference Introduction</font>
# ([course link](https://www.udemy.com/course/artificial-intelligence-reinforcement-learning-in-python/learn/lecture/6431036#overview))

# %% [markdown]
# ## <font color='darkblue'>TD(0) prediction</font>
# ([course link](https://www.udemy.com/course/artificial-intelligence-reinforcement-learning-in-python/learn/lecture/6431038#overview))

# %% [markdown]
# ## <font color='darkblue'>TD(0) prediction In Code</font>
# ([course link](https://www.udemy.com/course/artificial-intelligence-reinforcement-learning-in-python/learn/lecture/6431040#overview))
# * [td0_prediction.py](https://github.com/lazyprogrammer/machine_learning_examples/blob/master/rl/td0_prediction.py)

# %%
# %run -i td0_prediction.py
# Out:
# rewards:
# ---------------------------
#  0.00| 0.00| 0.00| 1.00|
# ---------------------------
#  0.00| 0.00| 0.00|-1.00|
# ---------------------------
#  0.00| 0.00| 0.00| 0.00|
# values:
# ---------------------------
#  0.79| 0.89| 0.98| 0.00|
# ---------------------------
#  0.70| 0.00|-0.98| 0.00|
# ---------------------------
#  0.61|-0.78|-0.89|-0.98|
# policy:
# ---------------------------
#   R  |  R  |  R  |     |
# ---------------------------
#   U  |     |  R  |     |
# ---------------------------
#   U  |  R  |  R  |  U  |

# %% [markdown]
# ## <font color='darkblue'>SARSA</font>
# ([course link](https://www.udemy.com/course/artificial-intelligence-reinforcement-learning-in-python/learn/lecture/6431042#overview))

# %% [markdown]
# ## <font color='darkblue'>SARSA In Code</font>
# ([course link](https://www.udemy.com/course/artificial-intelligence-reinforcement-learning-in-python/learn/lecture/6431044#overview))
# * [sarsa.py](https://github.com/lazyprogrammer/machine_learning_examples/blob/master/rl/sarsa.py)

# %%
# %run -i sarsa.py
# Out:
# rewards:
# ---------------------------
#  0.00| 0.00| 0.00| 1.00|
# ---------------------------
#  0.00| 0.00| 0.00|-1.00|
# ---------------------------
#  0.00| 0.00| 0.00| 0.00|
# it: 0
# it: 2000
# it: 4000
# it: 6000
# it: 8000
# update counts:
# ---------------------------
#  0.20| 0.19| 0.19| 0.00|
# ---------------------------
#  0.20| 0.00| 0.01| 0.00|
# ---------------------------
#  0.20| 0.01| 0.01| 0.00|
# values:
# ---------------------------
#  0.79| 0.85| 1.00| 0.00|
# ---------------------------
#  0.71| 0.00| 0.90| 0.00|
# ---------------------------
#  0.63| 0.61| 0.73| 0.31|
# policy:
# ---------------------------
#   R  |  R  |  R  |     |
# ---------------------------
#   U  |     |  U  |     |
# ---------------------------
#   U  |  R  |  U  |  L  |

# %% [markdown]
# ## <font color='darkblue'>Q Learning</font>
# ([course link](https://www.udemy.com/course/artificial-intelligence-reinforcement-learning-in-python/learn/lecture/6431046#overview))
