# %% [markdown]
# ## <font color='darkblue'>Approximation Methods Section Introduction</font>
# ([course link](https://www.udemy.com/course/artificial-intelligence-reinforcement-learning-in-python/learn/lecture/6431538#overview))
# * Review linear regression, stochastic gradient descent
# * Feature engineering
# * Approximation for prediction
# * Approximation for control

# %% [markdown]
# ## <font color='darkblue'>Linear Models for Reinforcement Learning</font>
# ([course link](https://www.udemy.com/course/artificial-intelligence-reinforcement-learning-in-python/learn/lecture/6431540#overview))

# %% [markdown]
# ## <font color='darkblue'>Feature Engineering</font>
# ([course link](https://www.udemy.com/course/artificial-intelligence-reinforcement-learning-in-python/learn/lecture/6431674#overview))

# %% [markdown]
# ## <font color='darkblue'>Approximation Methods for Prediction</font>
# ([course link](https://www.udemy.com/course/artificial-intelligence-reinforcement-learning-in-python/learn/lecture/26536098#overview))
# * Notation of $x = φ(s)$
#   * `s` is the "state" returned by environment
#   * `x` is the "feature" after transforming the state

# %% [markdown]
# ## <font color='darkblue'>Approximation Methods for Prediction Code</font>
# ([course link](https://www.udemy.com/course/artificial-intelligence-reinforcement-learning-in-python/learn/lecture/26536102#overview))
# * [`approx_prediction.py`](https://github.com/lazyprogrammer/machine_learning_examples/blob/master/rl/approx_prediction.py)

# %%
# %run -i 'approx_prediction.py'
# Out:
# rewards:
# ---------------------------
#  0.00| 0.00| 0.00| 1.00|
# ---------------------------
#  0.00| 0.00| 0.00|-1.00|
# ---------------------------
#  0.00| 0.00| 0.00| 0.00|
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [00:07<00:00, 1388.91it/s]
# values:
# ---------------------------
#  0.74| 0.82| 0.91| 0.00|
# ---------------------------
#  0.66| 0.00|-0.83| 0.00|
# ---------------------------
#  0.56|-0.58|-1.04|-0.94|
#
# policy:
# ---------------------------
#   R  |  R  |  R  |     |
# ---------------------------
#   U  |     |  R  |     |
# ---------------------------
#   U  |  R  |  R  |  U  |

# %% [markdown]
# ## <font color='darkblue'>Approximation Methods for Control</font>
# ([course link](https://www.udemy.com/course/artificial-intelligence-reinforcement-learning-in-python/learn/lecture/26536130#overview))

# %% [markdown]
# ## <font color='darkblue'>Approximation Methods for Control In Code</font>
# ([course link](https://www.udemy.com/course/artificial-intelligence-reinforcement-learning-in-python/learn/lecture/26536132#overview))
# * [`approx_control.py`](https://github.com/lazyprogrammer/machine_learning_examples/blob/master/rl/approx_control.py)

# %%
# %run -i 'approx_control.py'
# Out:
# rewards:
# ---------------------------
#  0.00| 0.00| 0.00| 1.00|
# ---------------------------
#  0.00| 0.00| 0.00|-1.00|
# ---------------------------
#  0.00| 0.00| 0.00| 0.00|
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20000/20000 [01:36<00:00, 206.43it/s]
# values:
# ---------------------------
#  0.81| 0.90| 0.99| 0.00|
# ---------------------------
#  0.72| 0.00| 0.89| 0.00|
# ---------------------------
#  0.66| 0.60| 0.76| 0.02|
#
# policy:
# ---------------------------
#   R  |  R  |  R  |     |
# ---------------------------
#   U  |     |  U  |     |
# ---------------------------
#   U  |  U  |  U  |  D  |
#
# state_visit_count:
#          0        1        2        3
# 0  22346.0  22226.0  21622.0  19952.0
# 1  22598.0      0.0    765.0     48.0
# 2  22575.0   1737.0    635.0   1538.0

# %% [markdown]
# ## <font color='darkblue'>CartPole</font>
# ([course link](https://www.udemy.com/course/artificial-intelligence-reinforcement-learning-in-python/learn/lecture/26536136#overview))
# * Classic problem in control theory - if you ever get to take a class in college on control, you'll get to build this (the controller) in real life:
#
# ![CartPole](images/1.PNG)

# %% [markdown]
# ## <font color='darkblue'>CartPole In Code</font>
# ([course link](https://www.udemy.com/course/artificial-intelligence-reinforcement-learning-in-python/learn/lecture/26536140#overview))
# * [`cartpole.py`](https://github.com/lazyprogrammer/machine_learning_examples/blob/master/rl/cartpole.py)

# %%
# %run -i "cartpole.py"
# Out:
# Episode reward: 10.0
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████| 1500/1500 [01:15<00:00, 19.77it/s]
# Average test reward: 116.4
# Episode reward: 126.0

# %% [markdown]
# ## <font color='darkblue'>Approximation Methods Exercises</font>
# ([course link](https://www.udemy.com/course/artificial-intelligence-reinforcement-learning-in-python/learn/lecture/26536568#overview))
# 1. Try other feature expansions. E.g. Polynomial, anything else in scikit-learn you find interesting.
# 2. Other methods other than Q-Learning. E.g. Monte Carlo, SARSA.
# 3. Does batch gradient descent work? (E.g. For Monte Carlo, after playing one episode, we have a batch of returns for all states.)
# 4. If you're familiar with Keras, Tensorflow, or PyTorch, use a neural network.
# 5. Different way to encode actions

# %% [markdown]
# ## <font color='darkblue'>Approximation Methods Section Summary</font>
# ([course link](https://www.udemy.com/course/artificial-intelligence-reinforcement-learning-in-python/learn/lecture/26536144)) <font size='3ptx'><b>"All data is the same" - Lazy Programmer's Famous Rule</b></font>
# * For modern problems, like Chess, Go, Video games, and autonomous vehicles, tabular methods are too limited.
# * Linear regression review, stochastic gradient descent.
# * Feature expansions; RBF kernel
# * Function approximation for prediction
# * Function approximation for control
# * CartPole/OpenAI Gym
# * Gridworld is still critical - explore new methods while keeping the environment constant
